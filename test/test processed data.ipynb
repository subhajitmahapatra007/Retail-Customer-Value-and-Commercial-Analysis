# %%
import pandas as pd

test_df = pd.read_csv("../dataset/processed/updated_customer_shopping_behaviour_data.csv")

# %%
test_df
# Out:
#       customer_id  age  gender  ... frequency_of_purchases     age_group  purchase_frequency_days
# 0               1   55    Male  ...            Fortnightly   Middle_Aged                       14
# 1               2   19    Male  ...            Fortnightly   Young_Adult                       14
# 2               3   50    Male  ...                 Weekly   Middle_Aged                        7
# 3               4   21    Male  ...                 Weekly   Young_Adult                        7
# 4               5   45    Male  ...               Annually  Senior_Adult                      365
# ...           ...  ...     ...  ...                    ...           ...                      ...
# 3895         3896   40  Female  ...                 Weekly  Senior_Adult                        7
# 3896         3897   52  Female  ...              Bi-Weekly   Middle_Aged                       14
# 3897         3898   46  Female  ...              Quarterly   Middle_Aged                       90
# ...

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   customer_id              3900 non-null   int64
#  1   age                      3900 non-null   int64
#  2   gender                   3900 non-null   object
#  3   item_purchased           3900 non-null   object
#  4   category                 3900 non-null   object
#  5   purchase_amount          3900 non-null   int64
#  6   location                 3900 non-null   object
#  7   size                     3900 non-null   object
#  8   color                    3900 non-null   object
#  9   season                   3900 non-null   object
#  10  review_rating            3900 non-null   float64
#  11  subscription_status      3900 non-null   object
#  12  shipping_type            3900 non-null   object
#  13  discount_applied         3900 non-null   object
# ...

# %%
test_df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'previous_purchases', 'payment_method',
#        'frequency_of_purchases', 'age_group', 'purchase_frequency_days'],
#       dtype='object')

# %%
test_df.isnull().sum()
# Out:
# customer_id                0
# age                        0
# gender                     0
# item_purchased             0
# category                   0
# purchase_amount            0
# location                   0
# size                       0
# color                      0
# season                     0
# review_rating              0
# subscription_status        0
# shipping_type              0
# discount_applied           0
# previous_purchases         0
# payment_method             0
# frequency_of_purchases     0
# age_group                  0
# purchase_frequency_days    0
# dtype: int64

# %%
test_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Find unique values of every columns along with their numbers and Datatype
for column in test_df.columns:
    print(f"Number of Unique Values of {column} is ",test_df[column].nunique(),
          f" And Datatype is ",test_df[column].dtype)
    print(f"\nUnique Values of {column} : \n",test_df[column].unique())
    print('*'*50)
# Out:
# Number of Unique Values of customer_id is  3900  And Datatype is  int64
#
# Unique Values of customer_id :
#  [   1    2    3 ... 3898 3899 3900]
# **************************************************
# Number of Unique Values of age is  53  And Datatype is  int64
#
# Unique Values of age :
#  [55 19 50 21 45 46 63 27 26 57 53 30 61 65 64 25 52 66 31 56 18 38 54 33
#  36 35 29 70 69 67 20 39 42 68 49 59 47 40 41 48 22 24 44 37 58 32 62 51
#  28 43 34 23 60]
# **************************************************
# Number of Unique Values of gender is  2  And Datatype is  object
#
# Unique Values of gender :
#  ['Male' 'Female']
# **************************************************
# Number of Unique Values of item_purchased is  25  And Datatype is  object
#
# Unique Values of item_purchased :
#  ['Blouse' 'Sweater' 'Jeans' 'Sandals' 'Sneakers' 'Shirt' 'Shorts' 'Coat'
#  'Handbag' 'Shoes' 'Dress' 'Skirt' 'Sunglasses' 'Pants' 'Jacket' 'Hoodie'
# ...

# %%
test_df[['frequency_of_purchases','purchase_frequency_days']]
# Out:
#      frequency_of_purchases  purchase_frequency_days
# 0               Fortnightly                       14
# 1               Fortnightly                       14
# 2                    Weekly                        7
# 3                    Weekly                        7
# 4                  Annually                      365
# ...                     ...                      ...
# 3895                 Weekly                        7
# 3896              Bi-Weekly                       14
# 3897              Quarterly                       90
# 3898                 Weekly                        7
# 3899              Quarterly                       90
#
# [3900 rows x 2 columns]

# %%
test_df[['age','age_group']]
# Out:
#       age     age_group
# 0      55   Middle_Aged
# 1      19   Young_Adult
# 2      50   Middle_Aged
# 3      21   Young_Adult
# 4      45  Senior_Adult
# ...   ...           ...
# 3895   40  Senior_Adult
# 3896   52   Middle_Aged
# 3897   46   Middle_Aged
# 3898   44  Senior_Adult
# 3899   52   Middle_Aged
#
# [3900 rows x 2 columns]
